# %% [markdown]
# # MODULE 4 - Model Development
#  Ejercicios realizados por: Denisse Maria Ramirez Colmenero A01561497
#
#
#  **Subtema: Model Evaluation using Visualization**

# %% [markdown]
# - Regression Plot
#
# Sirve para estimar:
#     La relación entre dos variables
#     Medir la fuerza de la correlación
#     La dirección de la relación (+/-)
#
# Cada punto representa un punto target diferente.
# La línea ajustada representa el valor predecido.
#
# ![Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.01.49%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.01.49%20p.m..png)

# %%
import seaborn as sns 

sns.regplot(x='highwat-mpg', y='price', data=df)
plt.ylim(0,)

# %% [markdown]
# - Residual Plot
#
# Representa el error entre los valores Yhat-Y
#
# ![Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.04.49%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.04.49%20p.m..png)

# %%
import seaborn as sns 
sns.residplot(df['highway-mpg'], df['price'])

# %% [markdown]
# - Distribution Plot
#
# El valor predicho vs el valor real.
# Son útiles para visualizar modelos con más de una variable independiente o característica.
#
#
# Los grafica en cuadros segun esten mas cercanos a ese valor.
#
# ![Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.11.07%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.11.07%20p.m..png)

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.12.44%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%209.12.44%20p.m..png)

# %%
import seaborn as sns 
ax1 = sns.distplot(df['price'], hist=False, color='r', label='Actual Value')
sns.distplot(Yhay, hist=False, color='b', label='Fitted Values', ax=ax1)
