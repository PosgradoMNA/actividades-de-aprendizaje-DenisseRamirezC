# %% [markdown]
# # MODULE 4 - Model Development
#  Ejercicios realizados por: Denisse Maria Ramirez Colmenero A01561497
#
#
#  **Subtema: Measures for In-Sample Evaluation**

# %% [markdown]
# Determinar numericamente que tan bien que se ajusta el modelo a los datos.

# %% [markdown]
# - Mean Squared Error MSE:
#
# encontrar la diferencia entre el valor real y y el valor predicho yhat y luego se eleva al cuadrado.
#
# Los errores de cada par de valores (real y predecido), se suman y se dividen entre en numero de samples para determinar la media.

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(df['price'], Y_predict_simple_fit)

# %% [markdown]
# - R squared
#
# Coeficiente de determinación. Es una medida para determinar lo cerca que están los datos de la línea de regresión ajustada. ¿qué tan cerca están nuestros datos reales de nuestro modelo estimado?
#
# R squared = (1 - MSE of regression line / MSE of the avarage of the data)  ....valores entre 0 y 1.
#
# Si la variable x es un buen predictor, nuestro modelo debería funcionar mucho mejor que sólo la media.
#
# ![Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%2010.46.28%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%2010.46.28%20p.m..png)
#
#
# Si el MSE of regression line, es mas chico, quiere decir que es un buen modelo, por lo tanto R squared es cercano a 1.

# %%
X = df[['highway-mpg']]
Y = df['price']
lm.fit(X,Y)
lm.score(X,Y)#r squared
#es el porcentaje de la varianza de price que explica el simple linear model
