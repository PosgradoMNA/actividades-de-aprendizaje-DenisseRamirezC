# %% [markdown]
# # MODULE 5 - Model Evaluation
#  Ejercicios realizados por: Denisse Maria Ramirez Colmenero A01561497
#
#
#  **Subtema: Ridge Regression**

# %% [markdown]
# Ridge Regression previene el overfitting
#
# Cuando se presentan outliers en el conjunto de datos, un polinomio de orden alto tratará de pasar tambien por los outliers, lo cual hará que no siga la función para el resto de los datapoints. Si vemos la función polinomica de orden alto, veremos que sus coeficientes son muy altos.
#
# Para controlar que no se eleven mucho, Ridge Regression utiliza su parámetro alpha para regularlos.
# A mayor alpha, los coeficientes disminuyen, pero no debemos elevar mucho alpha ya que los coeficientes pueden tender a cero y caer en el underfitting.
#
#
# Para seleccionar el valor de alpha usamos cross validation:

# %%
from sklearn.linear_model import Ridge
RigeModel = Ridge(alpha=0.1)
RigeModel.fit(X,y)
Yhat = RigeModel.predict(X)

#Aqui se utiliza el conjunto de validación, que sirve precisamente para escoger parametros como alpha
#Se repite el proceso de entrenamiento, prediccion y obtencion de r-squared con diferentes alphas y seleccionamos
#la que de mayor r-squared (u otra metrica)

# %% [markdown]
# A medida que aumenta alpha, la R-squared de los datos de prueba disminuye.
# Training data = red
# Validation data = blue
# eje x = alpha
# eje y = r-squared
# ![Captura%20de%20Pantalla%202022-11-04%20a%20la%28s%29%205.43.52%20p.m..png](attachment:Captura%20de%20Pantalla%202022-11-04%20a%20la%28s%29%205.43.52%20p.m..png)
