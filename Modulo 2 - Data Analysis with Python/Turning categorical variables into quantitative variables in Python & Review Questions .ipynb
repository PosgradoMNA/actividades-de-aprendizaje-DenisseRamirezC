# %% [markdown]
# # MODULE 2 - Data Wrangling
#
# Ejercicios realizados por: Denisse Maria Ramirez Colmenero A01561497
#
#
# Subject: Turning categorical variables into quantitative variables in Python & Review Questions

# %% [markdown]
# Encode the values by adding new features corresponding to each unique element in the
# original feature we would like to encode.
# Technique: One hot encoding
# ![Captura%20de%20Pantalla%202022-10-16%20a%20la%28s%29%201.19.51%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-16%20a%20la%28s%29%201.19.51%20p.m..png)

# %%
import pandas 
pandas.get_dummies(df["fuel"])#generates a list of numbers, each one corresponding to a particular category of the variable.

# %% [markdown]
# REVIEW QUESTIONS
#
#
# 1.- Consider the dataframe df. What is the result of the following operation: df['symbolling'] = df['symbolling'] + 1? R: Every element in the column "symbolling" will increase by one.
#
#
# 2.- Consider the dataframe df. What does the command df.rename(columns={'a':'b'}) change about the dataframe df?
# R: Nothing. You must set the parameter "inplace = True".
#
# 3.- Consider the dataframe "df". What is the result of the following operation df['price'] = df['price'].astype(int)? R:Convert or cast the column 'price' to an integer value.
#
# 4.- Consider the column of the dataframe df['a']. The column has been standardized. What is the standard deviation of the values as a result of applying the following operation: df['a'].std()? R: 1
#
# 5.A - Consider the column of the dataframe, df['Fuel'], with two values: 'gas' and' diesel'. What will be the name of the new columns pd.get_dumies(df['Fuel']) ? R: gas and diesel
#
# 5.B - What are the values of the new columns from part 5a)? R: 1 and 0.
