# %% [markdown]
# # MODULE 3 - Data Wrangling
#  Ejercicios realizados por: Denisse Maria Ramirez Colmenero A01561497
#
#
#  Subtemas: GroupBy in Python

# %%
#para agrupar los datos por los diferente tipos (valores) de una variable y comparar sus resultados 
import pandas 
dataframe.Groupby() 
#puede aplicarse a variables categoricas, y a una o varias variables

# %%
#por ejemplo si queremos comparar el precio segun las variables "drive-whheels" y "body-style" de un dataset sobre carros 
df_test=df[['drive-wheels', 'body-style', 'price']]
df_group=df_test.groupby(['drive-wheels', 'body-style'], as_index=False).mean()
df_group

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%201.21.01%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%201.21.01%20p.m..png)

# %%
#para observar los resultados mejor, se puede convertir esta tabla una grafica pivot
df_pivot=df.group.pivot(index='drive-wheels', columns='body-style')

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%201.23.48%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%201.23.48%20p.m..png)

# %%
#o tambien con heatmaps 
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar()
plot.show()

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%201.26.34%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%201.26.34%20p.m..png)
