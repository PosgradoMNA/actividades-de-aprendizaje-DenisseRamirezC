# %% [markdown]
# # MODULE 3 - Data Wrangling
#  Ejercicios realizados por: Denisse Maria Ramirez Colmenero A01561497
#
#
#  Subtemas: Correlation & Correlation - Statistics

# %% [markdown]
# Correlation: indica si dos variables son interdependientes, si una cambia en el tiempo, como lo hace la otra.

# %%
#correlacion entre precio y engine size 
import seaborn as sns
sns.regplot(x='engine-size', y ='prices', data=df)
plt.ylim(0,)#muestra la correlación junto con una línea de regresion lineal

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.45.25%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.45.25%20p.m..png)

# %%
#correlacion entre otros dos features, highway-mpg y price
sns.regplot(x='highway-mpg', y ='prices', data=df)
plt.ylim(0,)

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.47.30%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.47.30%20p.m..png)
#
# Negative linear relationship.
# Como sigue siendo una linea empinada, la variable highwat-mpg sigue siendo una buena variable para predecir el precio del carro.
#
# Un ejemplo de una variable que no serviria para predecir el precio sería "peak-rpm", ya que no influye en el precio.

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.51.50%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.51.50%20p.m..png)

# %% [markdown]
# ------------------------------------------
# Correlation Statistics
#
# Pearson correlation: Mide la fuerza de correlación entre dos variables
# Devuelve dos valores:
#
# * Correlation coefficient:
# close to +1 = large positive relationship
# close to -1 = large negative relationship
# close to 0: no relationship
#
# * P-value:
# Que tan seguros estamos de la correlacion que calculamos
# ![Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.57.20%20p.m..png](attachment:Captura%20de%20Pantalla%202022-10-19%20a%20la%28s%29%202.57.20%20p.m..png)
#
#
#
# Strong correlation:
# - correlatiion coefficient close to +1 or -1 and a p_value less than 0.001

# %%
#ejemplo de correlacion fuerte 
#correlacion entre horsepower y price 
pearson_coef, p_value = stats.pearsonr(df["horsepower"], df["price"])

#arroja 0.81 y 9.35e-48

# %%
#tambien se puede crear un heatmap para ver la correlacion de entre todas las variables del dataset 
#de esta forma se puede ver mas facilmente que variables influyen en el precio del carro y cuales no.

# %% [markdown]
# 1. Consider the dataframe "df". What method provides the summary statistics?
# R: df.describe()
#
# 2. df_test = df['body-style', 'price']
# df_grp = df_test.groupby(['body-style'], as_index=False).mean()
# What are resulting values of df_grp[‘price’]?
# R:The average price for each body style.
#
# 3. Correlation implies causation
# R: False
#
# 4. What is the minimum possible value of Pearson's Correlation?
# R: -1
#
# 5. What is the Pearson correlation between variables X and Y if X=Y:
# r:
